# %%
import os.path as path
import os
import csv 
import json 
import pandas as pd
up = path.abspath(path.join('json_to_csv.ipynb' ,"../../../.."))

# %%
up
# Out:
# '/dih4/dih4_2/wimlds'

# %%
data_file = up + '/mkortas/detect-waste/annotations/annotat.csv'
json_path = up + '/TACO-master/data/annotations.json'
annot_folder = up + '/mkortas/detect-waste/annotations/'

# %%
with open(json_path) as json_file: 
    data = json.load(json_file)

# %%
def export_data(data, dtype, file):
    img = data[dtype] 
    data_file = open(file, 'w') 
    csv_writer = csv.writer(data_file) 
    count = 0
    for i in img: 
        if count == 0: 
            header = i.keys() 
            csv_writer.writerow(header) 
            count += 1
        csv_writer.writerow(i.values()) 
    data_file.close()

# %%
export_data(data, 'images', os.path.join(annot_folder,'data_file.csv'))
export_data(data, 'annotations', os.path.join(annot_folder,'data_file2.csv'))
export_data(data, 'categories', os.path.join(annot_folder,'data_file3.csv'))

# %%
data3 = pd.read_csv(os.path.join(annot_folder,'data_file3.csv'))
data2 = pd.read_csv(os.path.join(annot_folder,'data_file2.csv'))
data = pd.read_csv(os.path.join(annot_folder,'data_file.csv'))

# %%
data = data.rename(columns={"id": "image_id"})
data3 = data3.rename(columns={"id": "category_id"})
data2 = data2.merge(data, on='image_id', how='left')
data2 = data2.merge(data3, on='category_id', how='left')
data2 = data2.rename(columns={"supercategory": "class"})
data2 = data2.rename(columns={"file_name": "filename"})
data2['bbox'] = data2['bbox'].map(lambda x: x.lstrip('[').rstrip(']'))
data2[['xmin','ymin','xmax','ymax']] = data2.bbox.str.split(",",expand=True,)

# %%
data2
# Out:
#         id  image_id  category_id  \
# 0        1         0            6
# 1        2         1           18
# 2        3         1           14
# 3        4         2            5
# 4        5         2            7
# ...    ...       ...          ...
# 4779  4779      1498           16
# 4780  4780      1498            7
# 4781  4781      1499           39
# 4782  4782      1499           14
# 4783  4783      1499            6
#
#                                            segmentation          area  \
# 0     [[561.0, 1238.0, 568.0, 1201.0, 567.0, 1175.0,...  4.039540e+05
# 1     [[928.0, 1876.0, 938.0, 1856.0, 968.0, 1826.0,...  1.071260e+06
# 2     [[617.0, 383.0, 703.0, 437.0, 713.0, 456.0, 72...  9.958350e+04
# 3     [[670.0, 993.0, 679.0, 998.0, 684.0, 1001.0, 6...  7.383250e+04
# 4     [[647.0, 1028.0, 650.0, 1022.0, 653.0, 1016.0,...  9.150000e+02
# ...                                                 ...           ...
# 4779  [[386, 1557, 635, 1567, 986, 1556, 1178, 1550,...  5.032469e+05
# 4780  [[1057, 1824, 1041, 1793, 1042, 1758, 1062, 17...  1.449450e+04
# 4781  [[1368, 1775, 1099, 1331, 862, 1494, 1099, 1944]]  1.549541e+05
# 4782  [[1096, 1996, 1121, 2069, 1134, 2127, 1177, 22...  2.867500e+04
# 4783  [[1125, 1937, 1135, 2012, 1194, 2013, 1221, 20...  6.858950e+04
#
#                                                    bbox  iscrowd  width  \
# 0                           517.0, 127.0, 447.0, 1322.0        0   1537
# 1                            1.0, 457.0, 1429.0, 1519.0        0   1537
# 2                           531.0, 292.0, 1006.0, 672.0        0   1537
# 3                            632.0, 987.0, 500.0, 374.0        0   1537
# 4                              632.0, 989.0, 44.0, 51.0        0   1537
# ...                                                 ...      ...    ...
# 4779  228.7143, 1550.0476, 1007.9998999999999, 578.9...        0   1824
# 4780                 1041.3334, 1721.7142, 141.0, 138.0        0   1824
# 4781       862.0274, 1331.25, 505.97260000000006, 612.5        0   1824
# 4782                        966.0, 1996.0, 211.0, 336.0        0   1824
# 4783                       1125.0, 1858.0, 234.0, 510.0        0   1824
#
#       height            filename  ...  \
# 0       2049  batch_1/000006.jpg  ...
# 1       2049  batch_1/000008.jpg  ...
# 2       2049  batch_1/000008.jpg  ...
# 3       2049  batch_1/000010.jpg  ...
# 4       2049  batch_1/000010.jpg  ...
# ...      ...                 ...  ...
# 4779    4000  batch_9/000098.jpg  ...
# 4780    4000  batch_9/000098.jpg  ...
# 4781    4000  batch_9/000099.jpg  ...
# 4782    4000  batch_9/000099.jpg  ...
# 4783    4000  batch_9/000099.jpg  ...
#
#                                              flickr_url  \
# 0     https://farm66.staticflickr.com/65535/33978196...
# 1     https://farm66.staticflickr.com/65535/47803331...
# 2     https://farm66.staticflickr.com/65535/47803331...
# 3     https://farm66.staticflickr.com/65535/40888872...
# 4     https://farm66.staticflickr.com/65535/40888872...
# ...                                                 ...
# 4779  https://farm66.staticflickr.com/65535/48693804...
# 4780  https://farm66.staticflickr.com/65535/48693804...
# 4781  https://farm66.staticflickr.com/65535/48701147...
# 4782  https://farm66.staticflickr.com/65535/48701147...
# 4783  https://farm66.staticflickr.com/65535/48701147...
#
#                                                coco_url date_captured  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3                                                   NaN           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 4779  https://farm66.staticflickr.com/65535/48693804...           NaN
# 4780  https://farm66.staticflickr.com/65535/48693804...           NaN
# 4781  https://farm66.staticflickr.com/65535/48701147...           NaN
# 4782  https://farm66.staticflickr.com/65535/48701147...           NaN
# 4783  https://farm66.staticflickr.com/65535/48701147...           NaN
#
#                                          flickr_640_url  \
# 0     https://farm66.staticflickr.com/65535/33978196...
# 1     https://farm66.staticflickr.com/65535/47803331...
# 2     https://farm66.staticflickr.com/65535/47803331...
# 3     https://farm66.staticflickr.com/65535/40888872...
# 4     https://farm66.staticflickr.com/65535/40888872...
# ...                                                 ...
# 4779                                                NaN
# 4780                                                NaN
# 4781                                                NaN
# 4782                                                NaN
# 4783                                                NaN
#
#                       class                   name       xmin        ymin  \
# 0                    Bottle           Glass bottle      517.0       127.0
# 1                    Carton            Meal carton        1.0       457.0
# 2                    Carton           Other carton      531.0       292.0
# 3                    Bottle   Clear plastic bottle      632.0       987.0
# 4                Bottle cap     Plastic bottle cap      632.0       989.0
# ...                     ...                    ...        ...         ...
# 4779                 Carton           Drink carton   228.7143   1550.0476
# 4780             Bottle cap     Plastic bottle cap  1041.3334   1721.7142
# 4781  Plastic bag & wrapper  Other plastic wrapper   862.0274     1331.25
# 4782                 Carton           Other carton      966.0      1996.0
# 4783                 Bottle           Glass bottle     1125.0      1858.0
#
#                      xmax                ymax
# 0                   447.0              1322.0
# 1                  1429.0              1519.0
# 2                  1006.0               672.0
# 3                   500.0               374.0
# 4                    44.0                51.0
# ...                   ...                 ...
# 4779   1007.9998999999999   578.9999999999998
# 4780                141.0               138.0
# 4781   505.97260000000006               612.5
# 4782                211.0               336.0
# 4783                234.0               510.0
#
# [4784 rows x 21 columns]

# %%
data2['xmax'] = data2['xmax'].astype(float) + data2['width'].astype(float)
data2['ymax'] = data2['ymax'].astype(float) + data2['height'].astype(float)

# %%
#data2['flickr_url'] = data2['flickr_url'].map(lambda x: x[-48:])
#data2['flickr_url'] = data2['flickr_url'].map(lambda x: x.replace('flickr.com/',''))
#data2[['cos','path']] = data2.flickr_url.str.split("/",expand=True,)
#data2 = data2[['path','width','height','class','xmin','ymin','xmax','ymax']]
#data2 = data2.rename(columns={"path": "filename"})

# %%
data2 = data2[['filename','width','height','class','xmin','ymin','xmax','ymax']]
data2.to_csv(data_file,index=False)
